# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("Online Retail.xlsx")
print(data.head())
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
print(data.tail())
# Out:
#        Invoice StockCode                         Description  Quantity  \
# 525456  538171     22271                FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750        FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751      FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970  PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931              JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country
# 525456 2010-12-09 20:01:00   2.95      17530.0  United Kingdom
# 525457 2010-12-09 20:01:00   3.75      17530.0  United Kingdom
# 525458 2010-12-09 20:01:00   3.75      17530.0  United Kingdom
# 525459 2010-12-09 20:01:00   3.75      17530.0  United Kingdom
# 525460 2010-12-09 20:01:00   1.95      17530.0  United Kingdom

# %%
print(data.count())
# Out:
# Invoice        525461
# StockCode      525461
# Description    522533
# Quantity       525461
# InvoiceDate    525461
# Price          525461
# Customer ID    417534
# Country        525461
# dtype: int64

# %%
print(data.isnull().sum())
# Out:
# Invoice             0
# StockCode           0
# Description      2928
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    107927
# Country             0
# dtype: int64

# %%
data_clean = data.dropna()

# %%
print(data.count())
# Out:
# Invoice        525461
# StockCode      525461
# Description    522533
# Quantity       525461
# InvoiceDate    525461
# Price          525461
# Customer ID    417534
# Country        525461
# dtype: int64

# %%
data_clean = data.dropna(axis = 1)

# %%
print(data.count())
# Out:
# Invoice        525461
# StockCode      525461
# Description    522533
# Quantity       525461
# InvoiceDate    525461
# Price          525461
# Customer ID    417534
# Country        525461
# dtype: int64

# %%
summary = data.describe()
print(summary)
# Out:
#             Quantity                    InvoiceDate          Price  \
# count  525461.000000                         525461  525461.000000
# mean       10.337667  2010-06-28 11:37:36.845017856       4.688834
# min     -9600.000000            2009-12-01 07:45:00  -53594.360000
# 25%         1.000000            2010-03-21 12:20:00       1.250000
# 50%         3.000000            2010-07-06 09:51:00       2.100000
# 75%        10.000000            2010-10-15 12:45:00       4.210000
# max     19152.000000            2010-12-09 20:01:00   25111.090000
# std       107.424110                            NaN     146.126914
#
#          Customer ID
# count  417534.000000
# mean    15360.645478
# min     12346.000000
# 25%     13983.000000
# 50%     15311.000000
# 75%     16799.000000
# max     18287.000000
# std      1680.811316

# %%
#Columns :- Quantity , Price , InvoiceNo , CustomerID
# Calculate mean for Quantity column
mean_Quantity = data["Quantity"].mean()
print(mean_Quantity)
# Calculate mean for Price column
mean_Price = data["Price"].mean()
print(mean_Price)
# Out:
# 10.337667305470815
# 4.688834478676819

# %%
#Calculate Median for Quantity column
median_Quantity = data["Quantity"].median()
print(median_Quantity)
#Calculate Median for Price column
median_Price = data["Price"].median()
print(median_Price)
# Out:
# 3.0
# 2.1

# %%
#Calculate Mode for Quantity column
mode_Quantity = data["Quantity"].mode().iloc[0]
print(mode_Quantity)
#Calculate Mode for Price column
mode_Price = data["Price"].mode().iloc[0]
print(mode_Price)
# Out:
# 1
# 1.25

# %%
# Calculate range for Quantity columns
range_Quantity = data["Quantity"].max() - data["Quantity"].min()
print(range_Quantity)
# Calculate range for Price columns
range_Price = data["Price"].max() - data["Price"].min()
print(range_Price)
# Out:
# 28752
# 78705.45

# %%
# Calculate variance for Quantity columns
variance_values_Quantity = data["Quantity"].var()
print(variance_values_Quantity)
# Calculate variance for Price columns
variance_values_Price = data["Price"].var()
print(variance_values_Price)
# Out:
# 11539.93946704283
# 21353.07498140598

# %%
# Calculate standard deviation for Quantity columns
std_deviation_Quantity = data["Quantity"].std()
print(std_deviation_Quantity)
# Calculate standard deviation for Price columns
std_deviation_Price = data["Price"].std()
print(std_deviation_Price)
# Out:
# 107.4241102687978
# 146.1269139529265

# %%
# Calculate quartiles for Quantity columns
q1 = data["Quantity"].quantile(0.25)
q2 = data["Quantity"].quantile(0.50)  # same as median
q3 = data["Quantity"].quantile(0.75)

# Calculate interquartile range (IQR)
iqr = q3 - q1
print(iqr)
# Out:
# 9.0

# %%
# Calculate quartiles for Price columns
q1 = data["Price"].quantile(0.25)
q2 = data["Price"].quantile(0.50)  # same as median
q3 = data["Price"].quantile(0.75)

# Calculate interquartile range (IQR)
iqr = q3 - q1
print(iqr)
# Out:
# 2.96

# %%
"""Histograms:

Quantity: To visualize the distribution of the quantity of items ordered.
Price: To visualize the distribution of prices."""


# Histogram for Quantity
plt.hist(data['Quantity'], bins=30, color='skyblue')
plt.xlabel('Quantity')
plt.ylabel('Frequency')
plt.title('Distribution of Quantity')
plt.show()

# Histogram for Price
plt.hist(data['Price'], bins=30, color='salmon')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Distribution of Price')
plt.show()

# %%
"""Bar Plot:

Country: To visualize the number of transactions from different countries."""
# Bar plot for Country
country_counts = data['Country'].value_counts()
plt.figure(figsize=(10, 6))
country_counts.plot(kind='bar', color='green')
plt.xlabel('Country')
plt.ylabel('Number of Transactions')
plt.title('Number of Transactions by Country')
plt.xticks(rotation=45)
plt.show()

# %%
"""Scatter Plot:

Quantity vs. Price: To visualize the relationship between the quantity of items ordered and their prices."""
# Scatter plot for Quantity vs. Price
plt.scatter(data['Quantity'], data['Price'], color='red', alpha=0.5)
plt.xlabel('Quantity')
plt.ylabel('Price')
plt.title('Quantity vs. Price')
plt.show()

# %%
# Extract month and day of week
data['Month'] = data['InvoiceDate'].dt.month
data['DayOfWeek'] = data['InvoiceDate'].dt.dayofweek
# Calculate monthly sales
monthly_sales = data.groupby('Month')['Quantity'].sum()

# Identify the busiest month
busiest_month = monthly_sales.idxmax()
# Calculate sales by day of week
daily_sales = data.groupby('DayOfWeek')['Quantity'].sum()

# Identify the busiest day of the week (0 = Monday, 6 = Sunday)
busiest_day_of_week = daily_sales.idxmax()
# Print the busiest month and day of the week
print("Busiest Month:", busiest_month)
print("Busiest Day of the Week:", busiest_day_of_week)
# Out:
# Busiest Month: 11
# Busiest Day of the Week: 3

# %%
print(data.head())
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country  Month  DayOfWeek
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom     12          1
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom     12          1
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom     12          1
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom     12          1
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom     12          1

# %%
# Find the top selling products 
top_selling_products = data.groupby('Description')['Quantity'].sum().sort_values(ascending=False)
top_selling_product = top_selling_products.idxmax()
# Print the top-selling products
print("Top-Selling Products:")
print(top_selling_products)
print(f"\nTop Product : {top_selling_product}")
print()
# Find the top selling countries
top_selling_countries = data.groupby("Description")["Country"].sum().sort_values(ascending=False)
# Print the top-selling- countries
print("Top-Selling Countries : ")
print(top_selling_countries.head(5))
# Out:
# Top-Selling Products:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    57733
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     54698
# BROCADE RING PURSE                    47647
# PACK OF 72 RETRO SPOT CAKE CASES      46106
# ASSORTED COLOUR BIRD ORNAMENT         44925
#                                       ...
# Zebra invcing error                   -9000
# ebay sales                           -13630
# missing                              -15149
# given away                           -20000
# ?                                    -25373
# Name: Quantity, Length: 4681, dtype: int64
#
# Top Product : WHITE HANGING HEART T-LIGHT HOLDER
#
# Top-Selling Countries :
# Description
# HAPPY BIRTHDAY CARD TEDDY/CAKE                              West IndiesUnited Kingdom
# 3 BLACK CATS W HEARTS BLANK CARD    United KingdomUnited KingdomWest IndiesWest In...
# VINTAGE BEAD PINK SCARF             United KingdomUnited KingdomWest IndiesUnited ...
# SET/4 COLOURFUL MIXING BOWLS        United KingdomUnited KingdomUnspecifiedUnited ...
# IVORY SCULPTED RND CANDLE           United KingdomUnited KingdomUnited KingdomWest...
# Name: Country, dtype: object

# %%
# Create box plots for Quantity and Price
plt.figure(figsize=(12, 6))
sns.boxplot(data['Quantity'])
plt.title('Box Plot for Quantity')
plt.show()

plt.figure(figsize=(12, 6))
sns.boxplot(data['Price'])
plt.title('Box Plot for Price')
plt.show()

# %%
# Calculate IQR for Quantity
Q1 = data['Quantity'].quantile(0.25)
Q3 = data['Quantity'].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds to identify outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers in Quantity
outliers_quantity = data[(data['Quantity'] < lower_bound) | (data['Quantity'] > upper_bound)]

# Calculate IQR for Price
Q1 = data['Price'].quantile(0.25)
Q3 = data['Price'].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds to identify outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers in Price
outliers_unitprice = data[(data['Price'] < lower_bound) | (data['Price'] > upper_bound)]
print(f"Outliers in Quantity : {outliers_quantity}")
print(f"Outliers in Price : {outliers_unitprice}")
# Out:
# Outliers in Quantity :        Invoice StockCode                      Description  Quantity  \
# 3       489434     22041     RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232   STRAWBERRY CERAMIC TRINKET BOX        24
# 5       489434     22064       PINK DOUGHNUT TRINKET POT         24
# 6       489434     21871              SAVE THE PLANET MUG        24
# 10      489435     22195     HEART MEASURING SPOONS LARGE        24
# ...        ...       ...                              ...       ...
# 525283  538165     22988                SOLDIERS EGG CUP         72
# 525285  538165     37370       RETRO COFFEE MUGS ASSORTED        72
# 525303  538167     22086  PAPER CHAIN KIT 50'S CHRISTMAS         40
# 525335  538168     22952  60 CAKE CASES VINTAGE CHRISTMAS        24
# 525446  538171     22154      ANGEL DECORATION 3 BUTTONS         48
#
#                InvoiceDate  Price  Customer ID         Country  Month  \
# 3      2009-12-01 07:45:00   2.10      13085.0  United Kingdom     12
# 4      2009-12-01 07:45:00   1.25      13085.0  United Kingdom     12
# 5      2009-12-01 07:45:00   1.65      13085.0  United Kingdom     12
# 6      2009-12-01 07:45:00   1.25      13085.0  United Kingdom     12
# 10     2009-12-01 07:46:00   1.65      13085.0  United Kingdom     12
# ...                    ...    ...          ...             ...    ...
# 525283 2010-12-09 17:34:00   1.25      14031.0  United Kingdom     12
# 525285 2010-12-09 17:34:00   1.06      14031.0  United Kingdom     12
# 525303 2010-12-09 18:58:00   2.55      14713.0  United Kingdom     12
# 525335 2010-12-09 19:23:00   0.55      14702.0  United Kingdom     12
# 525446 2010-12-09 20:01:00   0.42      17530.0  United Kingdom     12
#
#         DayOfWeek
# 3               1
# 4               1
# 5               1
# 6               1
# 10              1
# ...           ...
# 525283          3
# 525285          3
# 525303          3
# 525335          3
# 525446          3
#
# [57870 rows x 10 columns]
# Outliers in Price :        Invoice StockCode                     Description  Quantity  \
# 35      489437     21360          JOY LARGE WOOD LETTERS         1
# 38      489437     35400     WOODEN BOX ADVENT CALENDAR          2
# 89      489439      POST                         POSTAGE         3
# 126     489444      POST                         POSTAGE         1
# 131     489445     22180                 RETRO SPOT LAMP         2
# ...        ...       ...                             ...       ...
# 525217  538156     22423        REGENCY CAKESTAND 3 TIER         6
# 525238  538163     21258      VICTORIAN SEWING BOX LARGE         1
# 525265  538163     21784                 SHOE SHINE BOX          2
# 525323  538167     20748           KENSINGTON COFFEE SET         1
# 525396  538171     22824  3 TIER SWEETHEART GARDEN SHELF         1
#
#                InvoiceDate   Price  Customer ID         Country  Month  \
# 35     2009-12-01 09:08:00    9.95      15362.0  United Kingdom     12
# 38     2009-12-01 09:08:00    8.95      15362.0  United Kingdom     12
# 89     2009-12-01 09:28:00   18.00      12682.0          France     12
# 126    2009-12-01 09:55:00  141.00      12636.0             USA     12
# 131    2009-12-01 09:57:00    9.95      17519.0  United Kingdom     12
# ...                    ...     ...          ...             ...    ...
# 525217 2010-12-09 16:53:00   12.75      15555.0  United Kingdom     12
# 525238 2010-12-09 17:27:00   12.75      17841.0  United Kingdom     12
# 525265 2010-12-09 17:27:00    9.95      17841.0  United Kingdom     12
# 525323 2010-12-09 18:58:00   12.75      14713.0  United Kingdom     12
# 525396 2010-12-09 20:01:00   35.95      17530.0  United Kingdom     12
#
#         DayOfWeek
# 35              1
# 38              1
# 89              1
# 126             1
# 131             1
# ...           ...
# 525217          3
# 525238          3
# 525265          3
# 525323          3
# 525396          3
#
# [35273 rows x 10 columns]

# %%
print(">>>Conclusion<<<<<")
print("Using Python for Exploratory data analysis makes easy to find the  mean , median and modes using the pandas library..\nIt becomes very easy to visualize the data in different types of graphs such as in Histograms , Scatter plots and in Bar plots")
print("Standard Deviation and variations can also be performed as pandas library has enriched with built in functions for\ndata analysis.")
print(">>>>Summarize<<<<<")
print("Firstly we have checked for any missing values and removed the missing values.")
print("By analyzing the sales trends over time we have come to know about busiest month and busiest days of week which \nwas in months - November and in Days of the week it was 3 - Wednesday")
# Out:
# >>>Conclusion<<<<<
# Using Python for Exploratory data analysis makes easy to find the  mean , median and modes using the pandas library..
# It becomes very easy to visualize the data in different types of graphs such as in Histograms , Scatter plots and in Bar plots
# Standard Deviation and variations can also be performed as pandas library has enriched with built in functions for
# data analysis.
# >>>>Summarize<<<<<
# Firstly we have checked for any missing values and removed the missing values.
# By analyzing the sales trends over time we have come to know about busiest month and busiest days of week which
# was in months - November and in Days of the week it was 3 - Wednesday
